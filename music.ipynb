# %% [markdown]
# <a href="https://colab.research.google.com/github/kiruthiga2003/music_genre_1/blob/main/music.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa.display

# %%
music_data = pd.read_csv('/content/file.csv')
music_data.head(5)
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# 1              2039.036516           213843.755497  ...   55.356403
# 2              1747.702312            76254.192257  ...   40.598766
# 3              1596.412872           166441.494769  ...   44.427753
# 4              1748.172116            88445.209036  ...   86.099236
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -1.690215   36.524071    -0.408979   41.597103    -2.303523   55.062923
# 1    -0.731125   60.314529     0.295073   48.120598    -0.283518   51.106190
# 2    -7.729093   47.639427    -1.816407   52.382141    -3.439720   46.639660
# 3    -3.319597   50.206673     0.636965   37.319130    -0.619121   37.259739
# 4    -5.454034   75.269707    -0.916874   53.613918    -4.404827   62.910812
#
#    mfcc20_mean  mfcc20_var  label
# 0     1.221291   46.936035  blues
# 1     0.531217   45.786282  blues
# 2    -2.231258   30.573025  blues
# 3    -3.407448   31.949339  blues
# 4   -11.703234   55.195160  blues
#
# [5 rows x 60 columns]

# %%
music_data['label'].value_counts()
# Out:
# label
# blues        100
# classical    100
# country      100
# disco        100
# hiphop       100
# jazz         100
# metal        100
# pop          100
# reggae       100
# rock         100
# Name: count, dtype: int64

# %%
import numpy as np
import seaborn as sns

# Computing the Correlation Matrix
spike_cols = [col for col in music_data.columns if 'mean' in col]

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16, 11));

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(music_data[spike_cols].corr(), cmap='YlGn')

plt.title('Heatmap for MEAN variables', fontsize = 20)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10);

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
music_data['label'] = label_encoder.fit_transform(music_data['label'])

# %%
X = music_data.drop(['label','filename'],axis=1)
y = music_data['label']

# %%
cols = X.columns
minmax = preprocessing.MinMaxScaler()
np_scaled = minmax.fit_transform(X)

# new data frame with the new scaled data.
X = pd.DataFrame(np_scaled, columns = cols)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
													test_size=0.3,
													random_state=111)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((700, 58), (300, 58), (700,), (300,))

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3

# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import catboost as cb
from xgboost import XGBClassifier

rf = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0)
cbc = cb.CatBoostClassifier(verbose=0, eval_metric='Accuracy', loss_function='MultiClass')
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)

for clf in (rf, cbc, xgb):
	clf.fit(X_train, y_train)
	preds = clf.predict(X_test)
	print(clf.__class__.__name__,accuracy_score(y_test, preds))
# Out:
# RandomForestClassifier 0.78
# CatBoostClassifier 0.8333333333333334
# XGBClassifier 0.7833333333333333

# %%
import tensorflow.keras as keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *

model = Sequential()

model.add(Flatten(input_shape=(58,)))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 58)                0
#
#  dense (Dense)               (None, 256)               15104
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 50314 (196.54 KB)
# Trainable params: 49802 (194.54 KB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %%
# compile the model
adam = keras.optimizers.Adam(lr=1e-4)
model.compile(optimizer=adam,
			loss="sparse_categorical_crossentropy",
			metrics=["accuracy"])

hist = model.fit(X_train, y_train,
				validation_data = (X_test,y_test),
				epochs = 100,
				batch_size = 32)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 22/22 [==============================] - 3s 22ms/step - loss: 1.8831 - accuracy: 0.3357 - val_loss: 2.2071 - val_accuracy: 0.1033
# Epoch 2/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.3245 - accuracy: 0.5186 - val_loss: 2.1550 - val_accuracy: 0.1400
# Epoch 3/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.0611 - accuracy: 0.6429 - val_loss: 2.1047 - val_accuracy: 0.1300
# Epoch 4/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.9238 - accuracy: 0.7057 - val_loss: 2.0243 - val_accuracy: 0.1900
# Epoch 5/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.8198 - accuracy: 0.7343 - val_loss: 1.9196 - val_accuracy: 0.3533
# Epoch 6/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.7396 - accuracy: 0.7571 - val_loss: 1.8304 - val_accuracy: 0.5067
# Epoch 7/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6926 - accuracy: 0.7900 - val_loss: 1.7275 - val_accuracy: 0.6000
# Epoch 8/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6362 - accuracy: 0.7729 - val_loss: 1.6352 - val_accuracy: 0.6533
# Epoch 9/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5588 - accuracy: 0.8257 - val_loss: 1.5526 - val_accuracy: 0.6633
# Epoch 10/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5139 - accuracy: 0.8429 - val_loss: 1.4331 - val_accuracy: 0.7200
# Epoch 11/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5249 - accuracy: 0.8129 - val_loss: 1.3443 - val_accuracy: 0.7200
# Epoch 12/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4663 - accuracy: 0.8400 - val_loss: 1.2507 - val_accuracy: 0.7400
# Epoch 13/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4414 - accuracy: 0.8500 - val_loss: 1.1617 - val_accuracy: 0.7533
# Epoch 14/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4104 - accuracy: 0.8714 - val_loss: 1.0699 - val_accuracy: 0.7467
# Epoch 15/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4104 - accuracy: 0.8686 - val_loss: 1.0758 - val_accuracy: 0.7167
# Epoch 16/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4067 - accuracy: 0.8829 - val_loss: 1.0146 - val_accuracy: 0.7200
# Epoch 17/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3576 - accuracy: 0.8886 - val_loss: 0.9075 - val_accuracy: 0.7700
# Epoch 18/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3359 - accuracy: 0.9086 - val_loss: 0.8815 - val_accuracy: 0.7633
# Epoch 19/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3301 - accuracy: 0.8843 - val_loss: 0.8447 - val_accuracy: 0.7700
# Epoch 20/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3127 - accuracy: 0.8871 - val_loss: 0.7933 - val_accuracy: 0.7800
# Epoch 21/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2944 - accuracy: 0.9029 - val_loss: 0.7686 - val_accuracy: 0.7767
# Epoch 22/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3196 - accuracy: 0.8929 - val_loss: 0.7802 - val_accuracy: 0.7567
# Epoch 23/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3015 - accuracy: 0.9071 - val_loss: 0.8029 - val_accuracy: 0.7400
# Epoch 24/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2810 - accuracy: 0.9114 - val_loss: 0.7740 - val_accuracy: 0.7267
# Epoch 25/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2754 - accuracy: 0.9029 - val_loss: 0.7751 - val_accuracy: 0.7600
# Epoch 26/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2219 - accuracy: 0.9329 - val_loss: 0.7985 - val_accuracy: 0.7500
# Epoch 27/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2128 - accuracy: 0.9329 - val_loss: 0.7953 - val_accuracy: 0.7533
# Epoch 28/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2188 - accuracy: 0.9329 - val_loss: 0.7732 - val_accuracy: 0.7567
# Epoch 29/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1906 - accuracy: 0.9457 - val_loss: 0.8103 - val_accuracy: 0.7700
# Epoch 30/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2142 - accuracy: 0.9314 - val_loss: 0.7834 - val_accuracy: 0.7800
# Epoch 31/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2105 - accuracy: 0.9229 - val_loss: 0.8402 - val_accuracy: 0.7533
# Epoch 32/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1788 - accuracy: 0.9543 - val_loss: 0.8038 - val_accuracy: 0.8000
# Epoch 33/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1589 - accuracy: 0.9600 - val_loss: 0.8030 - val_accuracy: 0.7700
# Epoch 34/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1483 - accuracy: 0.9629 - val_loss: 0.8613 - val_accuracy: 0.7533
# Epoch 35/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1665 - accuracy: 0.9486 - val_loss: 0.8456 - val_accuracy: 0.7800
# Epoch 36/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1715 - accuracy: 0.9429 - val_loss: 0.8908 - val_accuracy: 0.7533
# Epoch 37/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1686 - accuracy: 0.9429 - val_loss: 0.9777 - val_accuracy: 0.7533
# Epoch 38/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1275 - accuracy: 0.9700 - val_loss: 0.9035 - val_accuracy: 0.7767
# Epoch 39/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1604 - accuracy: 0.9514 - val_loss: 0.8771 - val_accuracy: 0.7800
# Epoch 40/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1506 - accuracy: 0.9557 - val_loss: 0.9081 - val_accuracy: 0.7800
# Epoch 41/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1190 - accuracy: 0.9629 - val_loss: 0.8975 - val_accuracy: 0.7567
# Epoch 42/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1156 - accuracy: 0.9671 - val_loss: 0.9830 - val_accuracy: 0.7400
# Epoch 43/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1175 - accuracy: 0.9700 - val_loss: 0.9221 - val_accuracy: 0.7700
# Epoch 44/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1755 - accuracy: 0.9414 - val_loss: 0.9315 - val_accuracy: 0.7400
# Epoch 45/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1279 - accuracy: 0.9614 - val_loss: 0.8702 - val_accuracy: 0.8033
# Epoch 46/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1178 - accuracy: 0.9643 - val_loss: 0.9690 - val_accuracy: 0.7567
# Epoch 47/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1070 - accuracy: 0.9700 - val_loss: 0.9604 - val_accuracy: 0.7467
# Epoch 48/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1214 - accuracy: 0.9714 - val_loss: 0.9320 - val_accuracy: 0.7600
# Epoch 49/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1259 - accuracy: 0.9629 - val_loss: 1.1049 - val_accuracy: 0.7233
# Epoch 50/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1279 - accuracy: 0.9600 - val_loss: 1.1195 - val_accuracy: 0.7400
# Epoch 51/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1246 - accuracy: 0.9543 - val_loss: 1.0460 - val_accuracy: 0.7433
# Epoch 52/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0872 - accuracy: 0.9771 - val_loss: 0.9801 - val_accuracy: 0.7600
# Epoch 53/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0954 - accuracy: 0.9729 - val_loss: 1.0368 - val_accuracy: 0.7700
# Epoch 54/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1071 - accuracy: 0.9686 - val_loss: 1.2213 - val_accuracy: 0.7400
# Epoch 55/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0920 - accuracy: 0.9729 - val_loss: 1.1027 - val_accuracy: 0.7500
# Epoch 56/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1069 - accuracy: 0.9586 - val_loss: 0.9850 - val_accuracy: 0.7400
# Epoch 57/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1008 - accuracy: 0.9714 - val_loss: 0.9796 - val_accuracy: 0.7567
# Epoch 58/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1056 - accuracy: 0.9686 - val_loss: 1.0343 - val_accuracy: 0.7667
# Epoch 59/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1164 - accuracy: 0.9657 - val_loss: 1.1449 - val_accuracy: 0.7300
# Epoch 60/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1031 - accuracy: 0.9671 - val_loss: 1.1270 - val_accuracy: 0.7500
# Epoch 61/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0837 - accuracy: 0.9771 - val_loss: 1.1409 - val_accuracy: 0.7333
# Epoch 62/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0884 - accuracy: 0.9757 - val_loss: 1.1301 - val_accuracy: 0.7467
# Epoch 63/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1178 - accuracy: 0.9571 - val_loss: 1.1167 - val_accuracy: 0.7433
# Epoch 64/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0910 - accuracy: 0.9729 - val_loss: 1.0703 - val_accuracy: 0.7600
# Epoch 65/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1083 - accuracy: 0.9700 - val_loss: 1.1475 - val_accuracy: 0.7333
# Epoch 66/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.9743 - val_loss: 1.2679 - val_accuracy: 0.7233
# Epoch 67/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1096 - accuracy: 0.9643 - val_loss: 1.0619 - val_accuracy: 0.7600
# Epoch 68/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0722 - accuracy: 0.9857 - val_loss: 1.0170 - val_accuracy: 0.7433
# Epoch 69/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0871 - accuracy: 0.9729 - val_loss: 1.1616 - val_accuracy: 0.7267
# Epoch 70/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0784 - accuracy: 0.9757 - val_loss: 1.2511 - val_accuracy: 0.7533
# Epoch 71/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0883 - accuracy: 0.9771 - val_loss: 1.2571 - val_accuracy: 0.7133
# Epoch 72/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0841 - accuracy: 0.9771 - val_loss: 1.1388 - val_accuracy: 0.7467
# Epoch 73/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0766 - accuracy: 0.9757 - val_loss: 1.2438 - val_accuracy: 0.7267
# Epoch 74/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0820 - accuracy: 0.9714 - val_loss: 1.2083 - val_accuracy: 0.7433
# Epoch 75/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0753 - accuracy: 0.9829 - val_loss: 1.1001 - val_accuracy: 0.7467
# Epoch 76/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0609 - accuracy: 0.9871 - val_loss: 1.0593 - val_accuracy: 0.7600
# Epoch 77/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0917 - accuracy: 0.9700 - val_loss: 1.1580 - val_accuracy: 0.7567
# Epoch 78/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0732 - accuracy: 0.9814 - val_loss: 1.3474 - val_accuracy: 0.7033
# Epoch 79/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0614 - accuracy: 0.9857 - val_loss: 1.1661 - val_accuracy: 0.7267
# Epoch 80/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0685 - accuracy: 0.9786 - val_loss: 1.0647 - val_accuracy: 0.7467
# Epoch 81/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0639 - accuracy: 0.9814 - val_loss: 1.2669 - val_accuracy: 0.7233
# Epoch 82/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0592 - accuracy: 0.9871 - val_loss: 1.2483 - val_accuracy: 0.7300
# Epoch 83/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0655 - accuracy: 0.9786 - val_loss: 1.1301 - val_accuracy: 0.7233
# Epoch 84/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0615 - accuracy: 0.9886 - val_loss: 1.3597 - val_accuracy: 0.7000
# Epoch 85/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0659 - accuracy: 0.9843 - val_loss: 1.1808 - val_accuracy: 0.7600
# Epoch 86/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0630 - accuracy: 0.9771 - val_loss: 1.1361 - val_accuracy: 0.7400
# Epoch 87/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0571 - accuracy: 0.9871 - val_loss: 1.3005 - val_accuracy: 0.7433
# Epoch 88/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0473 - accuracy: 0.9843 - val_loss: 1.2441 - val_accuracy: 0.7600
# Epoch 89/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0467 - accuracy: 0.9886 - val_loss: 1.1891 - val_accuracy: 0.7600
# Epoch 90/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0482 - accuracy: 0.9857 - val_loss: 1.1553 - val_accuracy: 0.7433
# Epoch 91/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0431 - accuracy: 0.9900 - val_loss: 1.2244 - val_accuracy: 0.7533
# Epoch 92/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0483 - accuracy: 0.9857 - val_loss: 1.3888 - val_accuracy: 0.7133
# Epoch 93/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 0.9814 - val_loss: 1.3554 - val_accuracy: 0.7100
# Epoch 94/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0690 - accuracy: 0.9771 - val_loss: 1.3255 - val_accuracy: 0.7400
# Epoch 95/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0696 - accuracy: 0.9757 - val_loss: 1.4454 - val_accuracy: 0.7233
# Epoch 96/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0575 - accuracy: 0.9857 - val_loss: 1.2452 - val_accuracy: 0.7300
# Epoch 97/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0669 - accuracy: 0.9786 - val_loss: 1.2504 - val_accuracy: 0.7400
# Epoch 98/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0617 - accuracy: 0.9800 - val_loss: 1.3744 - val_accuracy: 0.7333
# Epoch 99/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0492 - accuracy: 0.9886 - val_loss: 1.1969 - val_accuracy: 0.7500
# Epoch 100/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0583 - accuracy: 0.9800 - val_loss: 1.7310 - val_accuracy: 0.6967

# %%
test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
print(f"Test accuracy: {test_accuracy}")
# Out:
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7310 - accuracy: 0.6967
# Test accuracy: 0.6966666579246521

# %%
fig, axs = plt.subplots(2,figsize=(10,10))

# accuracy
axs[0].plot(hist.history["accuracy"], label="train")
axs[0].plot(hist.history["val_accuracy"], label="test")
axs[0].set_ylabel("Accuracy")
axs[0].legend()
axs[0].set_title("Accuracy")

# Error
axs[1].plot(hist.history["loss"], label="train")
axs[1].plot(hist.history["val_loss"], label="test")
axs[1].set_ylabel("Error")
axs[1].legend()
axs[1].set_title("Error")

plt.show()
